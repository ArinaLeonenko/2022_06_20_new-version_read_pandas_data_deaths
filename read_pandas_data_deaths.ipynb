# %%
import panda as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 import panda as pd
#
# ModuleNotFoundError: No module named 'panda'

# %%
data_deaths=pd.read_csv('Number of deaths by cause, World, 1990 to 2019.csv', sep=',')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 data_deaths=pd.read_csv('Number of deaths by cause, World, 1990 to 2019.csv', sep=',')
#
# NameError: name 'pd' is not defined

# %%
print(data_deaths)
# Out:
#      Entity;Code;Year;Number of executions (Amnesty International);Deaths - Meningitis - Sex: Both - Age: All Ages (Number);Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number);Deaths - Parkinson's disease - Sex: Both - Age: All Ages (Number);Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number);Deaths - Malaria - Sex: Both - Age: All Ages (Number);Deaths - Drowning - Sex: Both - Age: All Ages (Number);Deaths - Interpersonal violence - Sex: Both - Age: All Ages (Number);Deaths - Maternal disorders - Sex: Both - Age: All Ages (Number);Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number);Deaths - Drug use disorders - Sex: Both - Age: All Ages (Number);Deaths - Tuberculosis - Sex: Both - Age: All Ages (Number);Deaths - Cardiovascular diseases - Sex: Both - Age: All Ages (Number);Deaths - Lower respiratory infections - Sex: Both - Age: All Ages (Number);Deaths - Neonatal disorders - Sex: Both - Age: All Ages (Number);Deaths - Alcohol us
# ...

# %%
data_deaths['Entity'] = data_deaths['Entity'].str.replace(';','') #работает для одного столбца

# %%
data_deaths.replace(';','')
# Out:
#            Entity  Code   Year Number of executions (Amnesty International)  \
# 0     Afghanistan  AFG;   2007                                           15
# 1     Afghanistan  AFG;   2008                                           17
# 2     Afghanistan  AFG;   2009                                            0
# 3     Afghanistan  AFG;   2011                                            2
# 4     Afghanistan  AFG;   2012                                           14
# ...           ...   ...    ...                                          ...
# 7268     Zimbabwe   ZWE  20;15                                          NaN
# 7269     Zimbabwe   ZWE  20;16                                          NaN
# 7270     Zimbabwe   ZWE  20;17                                          NaN
# 7271     Zimbabwe   ZWE  20;18                                          NaN
# 7272     Zimbabwe   ZWE  20;19                                          NaN
#
# ...

# %%
data_deaths.replace(';','')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 data_deaths.replace(';','')
#
# NameError: name 'data_deaths' is not defined
