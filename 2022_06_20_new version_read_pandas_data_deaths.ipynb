# %%
import pandas as pd

# %%
data_deaths=pd.read_csv('Number of deaths by cause, World, 1990 to 2019.csv', sep=';')

# %%
print(data_deaths)
# Out:
#             Entity  Code   Year Number of executions (Amnesty International)  \
# 0     Afghanis;tan  AFG;   2007                                           15
# 1     Afghanis;tan  AFG;   2008                                           17
# 2     Afghanis;tan  AFG;   2009                                            0
# 3     Afghanis;tan  AFG;   2011                                            2
# 4     Afghanis;tan  AFG;   2012                                           14
# ...            ...   ...    ...                                          ...
# 7268     Zimbabwe;   ZWE  20;15                                          NaN
# 7269     Zimbabwe;   ZWE  20;16                                          NaN
# 7270     Zimbabwe;   ZWE  20;17                                          NaN
# 7271     Zimbabwe;   ZWE  20;18                                          NaN
# 7272     Zimbabwe;   ZWE  20;19                                          NaN
#
# ...

# %%
data_deaths['Entity'] = data_deaths['Entity'].str.replace(';','')

# %%
print(data_deaths)
# Out:
#            Entity  Code   Year Number of executions (Amnesty International)  \
# 0     Afghanistan  AFG;   2007                                           15
# 1     Afghanistan  AFG;   2008                                           17
# 2     Afghanistan  AFG;   2009                                            0
# 3     Afghanistan  AFG;   2011                                            2
# 4     Afghanistan  AFG;   2012                                           14
# ...           ...   ...    ...                                          ...
# 7268     Zimbabwe   ZWE  20;15                                          NaN
# 7269     Zimbabwe   ZWE  20;16                                          NaN
# 7270     Zimbabwe   ZWE  20;17                                          NaN
# 7271     Zimbabwe   ZWE  20;18                                          NaN
# 7272     Zimbabwe   ZWE  20;19                                          NaN
#
# ...

# %%
data_deaths['Code']=data_deaths['Code'].str.replace(';','')

# %%
print(data_deaths)
# Out:
#            Entity Code   Year Number of executions (Amnesty International)  \
# 0     Afghanistan  AFG   2007                                           15
# 1     Afghanistan  AFG   2008                                           17
# 2     Afghanistan  AFG   2009                                            0
# 3     Afghanistan  AFG   2011                                            2
# 4     Afghanistan  AFG   2012                                           14
# ...           ...  ...    ...                                          ...
# 7268     Zimbabwe  ZWE  20;15                                          NaN
# 7269     Zimbabwe  ZWE  20;16                                          NaN
# 7270     Zimbabwe  ZWE  20;17                                          NaN
# 7271     Zimbabwe  ZWE  20;18                                          NaN
# 7272     Zimbabwe  ZWE  20;19                                          NaN
#
#      Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# ...

# %%
data_deaths['Year']=data_deaths['Year'].str.replace(';','')

# %%
print(data_deaths)
# Out:
#            Entity Code  Year Number of executions (Amnesty International)  \
# 0     Afghanistan  AFG  2007                                           15
# 1     Afghanistan  AFG  2008                                           17
# 2     Afghanistan  AFG  2009                                            0
# 3     Afghanistan  AFG  2011                                            2
# 4     Afghanistan  AFG  2012                                           14
# ...           ...  ...   ...                                          ...
# 7268     Zimbabwe  ZWE  2015                                          NaN
# 7269     Zimbabwe  ZWE  2016                                          NaN
# 7270     Zimbabwe  ZWE  2017                                          NaN
# 7271     Zimbabwe  ZWE  2018                                          NaN
# 7272     Zimbabwe  ZWE  2019                                          NaN
#
#      Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# ...
